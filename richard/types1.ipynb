# %%
types=['enfj', 'enfp', 'entj', 'entp']






#imports

from random import random
from time import sleep




import random
# import multiprocessing
# from multiprocessing import Pool
from datetime import date
import snscrape.modules.twitter as sntwitter
import pandas as pd
import numpy as np
from wordcloud import WordCloud
import re
import matplotlib.pyplot as plt
import seaborn as sns
# plt.style.use('fivethirtyeight')
import nltk
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
import concurrent.futures

from copy import deepcopy
from pprint import pprint



import os

# import spacy
# nlp = spacy.load("en_core_web_sm")

 





tweet_count =10000 #this number is the last n tweets
dflist=[]
dfdict={}




dictcount=0
errornames=[]




tweets_df1=pd.DataFrame()
for type in types:
    type=type.upper()  
    
    

    text_query = type
    since_date = "2022-01-01"
    until_date = "2022-10-20"
    try:
        # Using OS library to call CLI commands in Python
         os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets1.json'.format(tweet_count, since_date, text_query, until_date))
         tweets_df2 = pd.read_json('text-query-tweets1.json', lines=True)
         tweets_df2['type']=[type for i in range(0,len(tweets_df2))] 
         display(tweets_df2)     
       
     
   
                  
         tweets_df1 = pd.concat([tweets_df1,tweets_df2 ],ignore_index=True)
         
    except:
    
        pass
# Out:
#                                _type  \
# 0     snscrape.modules.twitter.Tweet
# 1     snscrape.modules.twitter.Tweet
# 2     snscrape.modules.twitter.Tweet
# 3     snscrape.modules.twitter.Tweet
# 4     snscrape.modules.twitter.Tweet
# ...                              ...
# 9995  snscrape.modules.twitter.Tweet
# 9996  snscrape.modules.twitter.Tweet
# 9997  snscrape.modules.twitter.Tweet
# 9998  snscrape.modules.twitter.Tweet
# 9999  snscrape.modules.twitter.Tweet
#
#                                                     url  \
# 0     https://twitter.com/Cyclamen0/status/158288223...
# 1     https://twitter.com/enfj_71/status/15828814292...
# 2     https://twitter.com/typepairbot/status/1582880...
# 3     https://twitter.com/PortugasDAsta/status/15828...
# 4     https://twitter.com/kk_O3I8/status/15828793588...
# ...                                                 ...
# 9995  https://twitter.com/oleo91976257/status/157579...
# 9996  https://twitter.com/Enfj__0211/status/15757925...
# ...

# %%
# Setting variables to be used in format string command below

tweets_df1
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/Cyclamen0/status/158288223...
# 1  https://twitter.com/enfj_71/status/15828814292...
# 2  https://twitter.com/typepairbot/status/1582880...
# 3  https://twitter.com/PortugasDAsta/status/15828...
# 4  https://twitter.com/kk_O3I8/status/15828793588...
#
#                        date  \
# 0 2022-10-19 23:51:47+00:00
# 1 2022-10-19 23:48:35+00:00
# 2 2022-10-19 23:46:23+00:00
# 3 2022-10-19 23:42:40+00:00
# 4 2022-10-19 23:40:22+00:00
#
#                                              content  \
# 0  @Jimin_wifes ENFJ\n\n#مهسا_امینی \n#OpIran \n#...
# 1                  quase surtando e colocando trança
# 2                                ENFJ 5w4 x ISTP 2w3
# ...
